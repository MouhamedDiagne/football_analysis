# %%
# Tester que le modèle fonctionne bien


# %pip install opencv-python ultralytics deep-sort-realtime scikit-learn scipy numpy

import ultralytics
model = ultralytics.YOLO('yolov8n.pt')
print('Modele charge OK :', model.info())
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 4.5 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/40.2 MB 18.7 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/40.2 MB 20.2 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/40.2 MB 20.2 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/40.2 MB 20.2 MB/s eta 0:00:02
#    ------ --------------------------------- 6.6/40.2 MB 5.8 MB/s eta 0:00:06
#    ------ --------------------------------- 6.6/40.2 MB 5.8 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/40.2 MB 4.7 MB/s eta 0:00:08
#    ------- -------------------------------- 7.3/40.2 MB 4.2 MB/s eta 0:00:08
#    -------- ------------------------------- 8.1/40.2 MB 4.1 MB/s eta 0:00:08
# ...
